# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
from numpy import *

# %%
plt.figure()
ax = plt.axes()
x = linspace(0,1,100)
ax.plot(x, sin(x))
ax.plot(x,x**3)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
ax.lines
# Out:
# [<matplotlib.lines.Line2D at 0x7fd1f51fd7b8>,
#  <matplotlib.lines.Line2D at 0x7fd1f545dcc0>]

# %%
ax.lines.remove(ax.lines[0])
plt.draw()

# %%
F = ax.fill_between(x,0,x**4)
F

# %%
ax.collections.remove(F)
plt.draw()

# %%
T = ax.text(.4,.4,'A')

# %%
ax.texts.remove(ax.texts[0])
plt.draw()

# %%
if len(ax.texts) > 0:
    ax.texts.remove(ax.texts[0])

# %%
plt.figure()
ax = plt.axes()
ax.set_xlim(0,2)
ax.set_ylim(0,2)
plt.plot([1],[1],'ro')
A = ax.annotate('Red dot', xy=(1,1), xycoords='data',
                xytext=(1.3,1.3), 
                va="top", ha="right",
                bbox=dict(boxstyle="round", alpha=0.2),
                arrowprops=dict(
                          arrowstyle="->",
                          connectionstyle="angle,angleA=-95,angleB=35,rad=10"))
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
A
#ax.texts.remove(A)
#plt.draw()

# %%
f = plt.figure(figsize=(5,5))
plt.axes([.1,.1,.4,.8])
plt.axes([.6,.5,.4,.4])
# Out:
# <img src="data:image/png;base64,..." width="499.9999891627921">

# %%
f.axes.remove(f.axes[0])
plt.draw()
